# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Brian Kanyenje
# * Student pace: part time
# * Scheduled project review date/time: 24/01/2025
# * Instructor name: Veronica Isiaho
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!
import pandas as pd
import csv
import gzip
basics = pd.read_csv('zippedData/imdb.title.basics.csv.gz', compression ='gzip')
ratings = pd.read_csv('zippedData/imdb.title.ratings.csv.gz', compression ='gzip')
gross = pd.read_csv('zippedData/bom.movie_gross.csv.gz', compression ='gzip')

# %%
with gzip.open('zippedData/imdb.title.basics.csv.gz', mode='rt', encoding='utf-8') as f:
    df = csv.DictReader(f)
    title = list(df)

# %%
with gzip.open('zippedData/imdb.title.ratings.csv.gz', mode='rt', encoding='utf-8') as f:
    df1 = csv.DictReader(f)
    ratings = list(df1)

# %%
with gzip.open('zippedData/bom.movie_gross.csv.gz', mode='rt', encoding='utf-8') as f:
    df = csv.DictReader(f)
    gross = list(df)

# %%
for i in title:
    for j in gross:
        if i['primary_title'] in j['title']:
            print(i['primary_title'])

# %%
title
# Out:
# [{'tconst': 'tt0063540',
#   'primary_title': 'Sunghursh',
#   'original_title': 'Sunghursh',
#   'start_year': '2013',
#   'runtime_minutes': '175',
#   'genres': 'Action,Crime,Drama'},
#  {'tconst': 'tt0066787',
#   'primary_title': 'One Day Before the Rainy Season',
#   'original_title': 'Ashad Ka Ek Din',
#   'start_year': '2019',
#   'runtime_minutes': '114',
#   'genres': 'Biography,Drama'},
#  {'tconst': 'tt0069049',
#   'primary_title': 'The Other Side of the Wind',
#   'original_title': 'The Other Side of the Wind',
#   'start_year': '2018',
#   'runtime_minutes': '122',
#   'genres': 'Drama'},
#  {'tconst': 'tt0069204',
#   'primary_title': 'Sabse Bada Sukh',
#   'original_title': 'Sabse Bada Sukh',
#   'start_year': '2018',
#   'runtime_minutes': '',
#   'genres': 'Comedy,Drama'},
#  {'tconst': 'tt0100275',
#   'primary_title': 'The Wandering Soap Opera',
#   'original_title': 'La Telenovela Errante',
#   'start_year': '2017',
#   'runtime_minutes': '80',
# ...

# %%
ratings.head().sort_values(by='tconst')
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
gross.head().sort_values(by='foreign_gross', ascending=False)
# Out:
#                                          title studio  domestic_gross  \
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 0                                  Toy Story 3     BV     415000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 1     691300000  2010
# 2     664300000  2010
# 0     652000000  2010
# 3     535700000  2010
# 4     513900000  2010
